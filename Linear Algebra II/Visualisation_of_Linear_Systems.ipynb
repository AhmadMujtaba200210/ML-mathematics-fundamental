# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadMujtaba200210/ML-mathematics-fundamental/blob/develop/Visualisation_of_Linear_Systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Solving Linear Systems**

# %% [markdown]
# Equations:
#
#                   y=3x
#
#                 -5x+2y=2
# Rearranged 2nd equation to Isolate y:
#
#                 y= (2+5x)/2
#
#                 2y=2+5x

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

# %%
x= np.linspace(-10,10,1000) # start finish endpoints

# %%
y1=3*x

# %%
y2=1+(5*x)/2

# %%
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('y',rotation=0)
ax.set_xlim([0,3])
ax.set_ylim([0,8])
ax.plot(x,y1,c="green")
ax.plot(x,y2,c="brown")
plt.axvline(x=2,color="purple",linestyle="--")
plt.axhline(y=6,color="purple",linestyle="--")

# %% [markdown]
# ##Elimination Example
#
# In the Elimination example, the two equations in the system are:
#
#                         2x - 3y = 15
#                         4x + 10y = 14
# Both equations can be rearranged to isolate y. Starting with first equation:
#
#                         -3y = 15 -2x
#                         y = (15-2x)/-3 = -5 + 2x/3
# Then for the second equation:
#
#                         4x + 10y = 14
#                         2x + 5y = 7
#                         5y = 7 - 2x
#                         y = (7-2x)/5

# %%
y1 = -5 + (2*x)/3
y2 = (7-2*x)/5

# %%
_,ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('y')
plt.axvline(x=0, color= 'lightgray')
plt.axhline(y=0, color= 'lightgray')
ax.set_xlim([-2,10])
ax.set_ylim([-6,4])
ax.plot(x,y1,c='green')
ax.plot(x,y2,c='purple')

# %% [markdown]
# #Matrix Properties

# %% [markdown]
# ###Forbeinous Norm

# %%
x = np.array([[1,2],[3,4]])
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
(1**2+2**2 + 3**2 + 4**2)**(1/2)
# Out:
# 5.477225575051661

# %%
np.linalg.norm(x) # same function as for vector L2 norm
# Out:
# 5.477225575051661

# %%
x_pt= torch.tensor([[1,2],[3,4.]])

# %%
torch.norm(x_pt)
# Out:
# tensor(5.4772)

# %%
x_tf=tf.Variable([[1,2],[3,4.]])

# %%
tf.norm(x_tf)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=5.477226>

# %% [markdown]
# ## Matrix Multiplication

# %%
A=np.array([[3,4],[5,6],[7,8]])
A
# Out:
# array([[3, 4],
#        [5, 6],
#        [7, 8]])

# %%
B=np.array([1,2])
B
# Out:
# array([1, 2])

# %%
np.dot(A,B)
# Out:
# array([11, 17, 23])

# %% [markdown]
# #### with tensor flow

# %%
A_tf=

# %% [markdown]
# ### with pytorch

# %%
A_pt=torch.tensor([[3,4],[5,6],[7,8]])
A_pt
# Out:
# tensor([[3, 4],
#         [5, 6],
#         [7, 8]])

# %%
B_pt=torch.tensor([1,2])

# %%
torch.matmul(A_pt,B_pt)
# Out:
# tensor([11, 17, 23])

# %% [markdown]
# ##Symmetric Matrix

# %%
X_sym=np.array([[0,1,2],[1,7,8],[2,8,9]])
X_sym
# Out:
# array([[0, 1, 2],
#        [1, 7, 8],
#        [2, 8, 9]])

# %%
X_sym.T
# Out:
# array([[0, 1, 2],
#        [1, 7, 8],
#        [2, 8, 9]])

# %%
X_sym==X_sym.T
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True]])

# %%
I_matrix=torch.tensor([[1,0,0],[0,1,0],[0,0,1]])
I_matrix
# Out:
# tensor([[1, 0, 0],
#         [0, 1, 0],
#         [0, 0, 1]])

# %%
x_pt=torch.tensor([25,2,10])
x_pt
# Out:
# tensor([25,  2, 10])

# %%
torch.matmul(I_matrix,x_pt)
# Out:
# tensor([25,  2, 10])

# %% [markdown]
# ## Matrix Inversion

# %%
x=np.array([[4,2],[-5,-3]])
x
# Out:
# array([[ 4,  2],
#        [-5, -3]])

# %%
x_inv = np.linalg.inv(x)
x_inv
# Out:
# array([[ 1.5,  1. ],
#        [-2.5, -2. ]])

# %%
 y = np.array([4,-7])
 y
# Out:
# array([ 4, -7])

# %%
w = np.dot(x_inv,y)
w
# Out:
# array([-1.,  4.])

# %% [markdown]
# ## Orthogonal Matrix

# %%
matrix = np.array([[2/3,1/3,2/3],[-2/3,2/3,1/3],[1/3,2/3,-2/3]])
matrix
# Out:
# array([[ 0.66666667,  0.33333333,  0.66666667],
#        [-0.66666667,  0.66666667,  0.33333333],
#        [ 0.33333333,  0.66666667, -0.66666667]])

# %%
column_1 = matrix[:,0]
column_1
# Out:
# array([ 0.66666667, -0.66666667,  0.33333333])

# %%
column_2 = matrix[:,1]
column_2
# Out:
# array([0.33333333, 0.66666667, 0.66666667])

# %%
column_3 = matrix[:,2]
column_3
# Out:
# array([ 0.66666667,  0.33333333, -0.66666667])

# %% [markdown]
# showing orthogonal

# %%
np.dot(column_1,column_2)
# Out:
# 0.0

# %%
np.dot(column_1,column_3)
# Out:
# 0.0

# %%
np.dot(column_2,column_3)
# Out:
# 0.0

# %% [markdown]
# ##Eigen Vectors

# %% [markdown]
# Affine Transformation via Matrix Multiplication

# %%
import matplotlib.pyplot as plt

# %%
v = np.array([3,1])
v
# Out:
# array([3, 1])

# %%
def plot_vectors(vectors,colors):
  plt.figure()
  plt.axvline(x=0,color='lightgray')
  plt.axhline(y=0,color='lightgray')

  for i in range(len(vectors)):
    x = np.concatenate([[0,0],vectors[i]])
    plt.quiver([x[0]],[x[1]],[x[2]],[x[3]],
               angles='xy',scale_units='xy',scale=1,color=colors[i])

# %% [markdown]
# we will plot a graph in which a vector is stretches from 0 to 3 on x axis and 0 to 1 on y axis i.e. array = [3,1]

# %%
plot_vectors([v],['lightblue'])
plt.xlim(-1,5)
plt.ylim(-1,5)
# Out:
# (-1.0, 5.0)

# %% [markdown]
# Applying matrix ( multiplying matrix )

# %%
I = np.array([[1,0],[0,1]])
I
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
product = np.dot(I,v)
product
# Out:
# array([3, 1])

# %%
plot_vectors([product],['darkblue'])
plt.xlim(-1,5)
plt.ylim(-1,5)
# Out:
# (-1.0, 5.0)

# %% [markdown]
# Lets multiply a matrix with such matrix that will flip the matrix on x axis

# %%
E = np.array([[1,0],[0,-1]])
E
# Out:
# array([[ 1,  0],
#        [ 0, -1]])

# %%
Ev = np.dot(E,v)
Ev
# Out:
# array([ 3, -1])

# %%
plot_vectors([v,Ev],['darkblue','darkred'])
plt.xlim(-1,5)
plt.ylim(-1,5)
plt.title('Flipping matrix along x axis')
# Out:
# Text(0.5, 1.0, 'Flipping matrix along x axis')

# %%
F = np.array([[-1,0],[0,1]])
F
# Out:
# array([[-1,  0],
#        [ 0,  1]])

# %%
Fv = np.dot(F,v)
Fv
# Out:
# array([-3,  1])

# %%
plot_vectors([Fv,v],['blue','red'])
plt.xlim(-4,4)
plt.ylim(-1,5)
plt.title("Flippling Matrix along y axis")
# Out:
# Text(0.5, 1.0, 'Flippling Matrix along y axis')

# %% [markdown]
# So, this is affine transformation where we change in geometry such as direction and angles, where flipping a matrix is also a part of geometry.

# %% [markdown]
# A single matrix can apply multiple affine transformation such as flipping a matrix on x or y axis and then rotate to 45 degree

# %%
A = np.array([[-1,4],[2,-2]])
A
# Out:
# array([[-1,  4],
#        [ 2, -2]])

# %%
Av = np.dot(A,v)
Av
# Out:
# array([1, 4])

# %%
plot_vectors([Av,v],['blue','red'])
plt.xlim(-4,4)
plt.ylim(-1,5)
# Out:
# (-1.0, 5.0)
